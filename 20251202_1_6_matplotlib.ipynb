# %% [markdown]
# ### pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
X = np.arange(0,6,0.1) # 以 0.1 为单位,生成 0 到 6 的数据
y = np.sin(X)

# 绘制图形
plt.plot(X,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,6,0.1) # 以 0.1 为单位,生成 0 到 6 的数据
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,label = 'sin')
plt.plot(x,y2,label = 'cos',ls = '--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin & cos')
plt.legend()
plt.show()

# %% [markdown]
# ###  imshow

# %% [markdown]
# pyplot 中还提供了用于显示图像的方法 imshow()。另外，可以使用matplotlib.image模块的imread()方法读入图像。

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

plt.figure(figsize = (10,6))
img = imread('amber_grid.jpg')
plt.imshow(img)

# plt.axis('off')
# plt.grid(True)
plt.show()
